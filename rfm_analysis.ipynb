# %% [markdown]
# # RFM Analizi ile Müşteri Segmentasyonu
# **Veri Seti:** E-Commerce Data (Online Retail Dataset)

# %%
import pandas as pd
import numpy as np
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# Ayarlar
pd.set_option('display.float_format', '{:.2f}'.format)
plt.rcParams['figure.dpi'] = 150

DATA_PATH    = '/home/claude/rfm_project/data.csv'
FIGURES_PATH = '/home/claude/rfm_project/figures/'
REFERENCE_DATE = '2011-12-10'

print('✅ Kütüphaneler yüklendi')

# %% [markdown]
# ## 1. Veri Yükleme

# %%
df = pd.read_csv(DATA_PATH, encoding='unicode_escape')
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])
print(f'Satır: {df.shape[0]:,} | Sütun: {df.shape[1]}')
df.head()

# %% [markdown]
# ## 2. Veri Temizleme

# %%
# Buraya veri temizleme kodları gelecek

# %% [markdown]
# ## 3. RFM Hesaplama

# %%
# Buraya RFM kodları gelecek

# %% [markdown]
# ## 4. K-Means Kümeleme

# %%
# Buraya kümeleme kodları gelecek

# %% [markdown]
# ## 5. Cohort Analizi

# %%
# Buraya cohort kodları gelecek
